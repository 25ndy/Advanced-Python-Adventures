# %% [markdown]
# 1. not explicitly labeled
# 2. K-Means and Principal Component Analysis (PCA)
# 3. Centroid is the "average points of all points" In a triangle, it is the intersection of the three bisector/medians.
# 4. Under line 7, the blue points represent clusters and the stars represent initial centroids.
# 5. The closest centroid formula is the one that minimizes the magnitude between the position of X and position of the initial cluster point.
# 6. centroids is array, X is array, np.square is function, min_distance is int, idx is int
# 7. Purpose of line 9 is to see which centroids are the best for clustering the three groups.
# 8. All points have been clustered/classified to different centroid points accordingly.
# 9. This simply adds up all points, then divides by number of points. This is same as the formula for average point.
# 10. to show the multiple iterations to show how the centroids are getting better and actually becoming the true center of each cluster over time. It also shows that random initialization sometimes gets you good clusters.
# 11. from sklearn.cluster import KMeans km1= KMeans(3) km1.fit(X1)
# 12. n_clusters=# of clusters/centroids, init=sampling order, n_init=Number of times the k-means algorithm is run with different centroid seeds, max_iter=Maximum number of iterations of the k-means algorithm for a single run, tol=0.0001, verbose=0, random_state=None, copy_x=True, algorithm='lloyd'
# 13. How do obtain the cluster #/color # that best preserves the original photo quality while compressing?
# 14. X3 is an array.
# 15. z-score normalization.
# 16. 3Blue 1Brown
# 17. to normalize the data. mean is an array, std is an array, X_norm is an array, and U, S, V are all arrays from the SVD decomposition.
# 18. the long black arrow is the main direction of data variation, and the short green arrow shows the secondary direction. Basically, arrows show you which way the data is stretched out.
# 19. This graph is showing how each original data point gets "squished" from 2D down to 1D
# 20. from sklearn.decomposition import PCA pca= PCA(n_components= 2) pca_result= pca.fit_transform(X3)
# 21. X3 is the 2D toy dataset that was loaded earlier. n_components is how many principal components you want to keep.
# 22. (50, 2) means there are 50 data points and each one is now described by 2 principal components instead of the original features. the first principal component captures about 87% of all the variability in the data, and the second one captures the remaining ~13%. So together they capture 100%.
# 23. K-Means on actual face images and then PCA to project those faces into a lower dimension.
